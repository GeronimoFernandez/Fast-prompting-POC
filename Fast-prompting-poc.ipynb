# %%
# !pip install diffusers transformers accelerate

# %%
from huggingface_hub import login

login('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')

# %%
from huggingface_hub import hf_api
import requests

# Tu clave API de Hugging Face
api_key = "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"  # Reemplaza con tu clave API

# Define el prompt
prompt = "Genera una imagen publicitaria vibrante para un supermercado local. Muestra un carrito lleno de productos frescos como frutas, verduras y pan. En el fondo, incluye estantes bien organizados con carteles visibles de ofertas como '¡Hasta 50% de descuento en frutas y verduras!' y 'Promoción exclusiva de pan y lácteos'. Usa colores brillantes como verde y rojo para resaltar las ofertas. Añade un gran mensaje en la parte superior que diga '¡Aprovecha nuestras ofertas exclusivas!' y un texto adicional que diga 'Productos frescos al mejor precio'."

# URL de la API para la generación de imágenes con Stable Diffusion
url = "https://api-inference.huggingface.co/models/stabilityai/stable-diffusion-2-1"

# Realiza la solicitud POST a la API de Hugging Face
headers = {"Authorization": f"Bearer {api_key}"}
payload = {"inputs": prompt}
response = requests.post(url, headers=headers, json=payload)

# Si la solicitud es exitosa, guarda la imagen
if response.status_code == 200:
    with open("generated_image5.png", "wb") as f:
        f.write(response.content)
    print("Imagen generada y guardada.")
else:
    print("Error:", response.status_code)
# Out:
# Imagen generada y guardada.

# %%
from IPython.display import Image

# Mostrar la imagen generada en Colab
Image(filename='generated_image5.png')
